# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

def generate_batch_cbow(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch_cbow(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'as', 'of', 'originated', 'term']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  session.run(tf.initialize_all_variables())
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.789532
# Nearest to was: abbreviating, saltpeter, stimulated, merciful, mount, aesthetic, courtesy, flamenco,
# Nearest to new: lemnos, spectacularly, hobby, canceling, decreed, breastfeeding, arthurian, gordon,
# Nearest to can: foreigners, miscarriages, haploid, congested, obe, agathocles, easiest, lewiston,
# Nearest to b: fleetwood, grim, pedersen, dicots, deviant, soundtrack, ioannes, restroom,
# Nearest to these: potential, closeup, duchy, superimposed, letterboxes, guardians, nepal, qx,
# Nearest to four: watson, booting, gough, sucrose, coke, culp, ayahuasca, mascot,
# Nearest to when: onto, jesu, christa, summertime, senussi, watched, violent, gallium,
# Nearest to zero: repertoire, primates, unionism, accompaniments, takes, ecuador, surpassing, farms,
# Nearest to into: hypnotherapy, prd, iridium, ire, pocket, wetter, barrios, minucius,
# Nearest to over: presents, qui, glagolitic, dramatists, romana, rubies, karen, yours,
# Nearest to had: gallery, prostate, renn, obiang, digs, pogrom, revenge, good,
# Nearest to one: fairies, impunity, domo, librarians, driving, funchal, frontal, roe,
# Nearest to its: fret, windward, sesame, rallies, enrollment, appreciably, polished, chifley,
# Nearest to most: engaged, summand, exhausts, roo, underarm, joss, sculpted, humility,
# Nearest to i: mcbeal, methuen, coprocessor, configured, brink, prep, ariadne, toolkit,
# Nearest to american: pathway, geographically, southey, nobi, lignite, metropolitan, velde, vapors,
# Average loss at step 2000: 4.349237
# Average loss at step 4000: 3.863916
# Average loss at step 6000: 3.782121
# Average loss at step 8000: 3.688278
# Average loss at step 10000: 3.607068
# Nearest to was: is, were, had, has, by, be, nut, ammonium,
# Nearest to new: lemnos, spectacularly, ibanez, congress, gordon, hobby, drunk, pageant,
# Nearest to can: would, must, may, will, tdi, should, lewiston, fortifications,
# Nearest to b: d, fleetwood, kelvin, deviant, jimmu, cno, bukhara, claudius,
# Nearest to these: scrap, potential, superimposed, sauerkraut, several, moseley, many, cosa,
# Nearest to four: eight, three, six, five, seven, nine, two, zero,
# Nearest to when: senussi, however, that, does, onto, gravity, honduran, refute,
# Nearest to zero: five, nine, eight, seven, four, six, three, two,
# Nearest to into: to, iridium, from, minucius, by, oxfordshire, catastrophe, sorcerers,
# Nearest to over: euler, archelaus, glagolitic, presents, rubies, older, karen, dramatists,
# Nearest to had: has, was, have, maecenas, nsw, were, gershom, lucie,
# Nearest to one: two, three, eight, four, six, five, nine, seven,
# Nearest to its: his, their, the, each, a, unprepared, chief, ducal,
# Nearest to most: sergius, richmond, jotham, bennington, councillors, commonwealth, gorilla, aggressor,
# Nearest to i: formosa, newly, prep, britannia, benoit, he, lied, dcc,
# Nearest to american: pinned, and, krupp, pathway, malaysian, endian, wikis, aoun,
# Average loss at step 12000: 3.605397
# Average loss at step 14000: 3.568304
# Average loss at step 16000: 3.407166
# Average loss at step 18000: 3.452152
# Average loss at step 20000: 3.539939
# Nearest to was: is, were, became, has, had, nut, makes, does,
# Nearest to new: ibanez, lemnos, congress, drunk, path, spectacularly, distant, france,
# Nearest to can: would, may, will, must, could, should, to, cannot,
# Nearest to b: d, triplet, fleetwood, ideological, recorders, jimmu, and, deviant,
# Nearest to these: many, several, some, moseley, scrap, such, superimposed, all,
# Nearest to four: seven, five, eight, six, three, nine, two, zero,
# Nearest to when: if, but, however, does, after, conjugations, that, since,
# Nearest to zero: five, six, four, seven, three, eight, nine, two,
# Nearest to into: from, iridium, catastrophe, by, with, adair, minucius, before,
# Nearest to over: euler, karen, archelaus, lep, hebrew, older, glagolitic, pokey,
# Nearest to had: has, have, was, were, been, are, maecenas, nsw,
# Nearest to one: two, three, seven, four, eight, six, five, nine,
# Nearest to its: their, his, each, the, emergency, brilliant, convicts, bello,
# Nearest to most: more, many, councillors, some, alastair, commonwealth, jotham, bennington,
# Nearest to i: ii, iii, touchstone, you, champaign, they, hmg, rod,
# Nearest to american: french, german, british, english, wikis, courant, catv, tagore,
# Average loss at step 22000: 3.495784
# Average loss at step 24000: 3.489893
# Average loss at step 26000: 3.482023
# Average loss at step 28000: 3.475128
# Average loss at step 30000: 3.496911
# Nearest to was: is, had, were, has, became, nut, been, be,
# Nearest to new: path, distant, lemnos, persian, congress, marrying, janissaries, drunk,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to b: d, hx, elgin, sailboat, jellyfish, abijah, geographers, xvi,
# Nearest to these: some, many, several, their, such, they, are, moseley,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to when: if, after, where, but, however, before, although, alchemist,
# Nearest to zero: five, eight, seven, four, nine, three, six, two,
# Nearest to into: from, under, adair, catastrophe, before, iridium, averse, prd,
# Nearest to over: lep, euler, archelaus, karen, romana, pokey, contraceptive, older,
# Nearest to had: has, have, was, were, is, ausgleich, been, became,
# Nearest to one: two, seven, four, five, nine, three, eight, six,
# Nearest to its: their, the, his, vocals, anhydrous, sterne, bmp, molotov,
# Nearest to most: more, some, many, jotham, theological, commonwealth, principle, aggressor,
# Nearest to i: ii, you, they, iii, formosa, touchstone, snapper, rod,
# Nearest to american: english, french, british, german, courant, russian, catv, def,
# Average loss at step 32000: 3.502066
# Average loss at step 34000: 3.491088
# Average loss at step 36000: 3.456689
# Average loss at step 38000: 3.296245
# Average loss at step 40000: 3.428398
# Nearest to was: is, became, had, were, has, nut, be, been,
# Nearest to new: path, marrying, distant, second, persian, lemnos, optimization, henceforth,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to b: d, c, j, h, yards, footballer, n, ch,
# Nearest to these: some, many, several, they, both, geodesic, such, moseley,
# Nearest to four: six, three, eight, five, two, seven, nine, one,
# Nearest to when: if, after, while, but, envisaged, with, thorndike, before,
# Nearest to zero: seven, five, nine, eight, six, three, four, two,
# Nearest to into: from, adair, before, iridium, catastrophe, through, repackaged, averse,
# Nearest to over: lep, euler, through, scans, melaka, emmy, between, adhered,
# Nearest to had: has, have, was, were, surged, been, became, ausgleich,
# Nearest to one: seven, four, two, six, five, nine, three, eight,
# Nearest to its: their, his, the, brilliant, her, convicts, fret, bello,
# Nearest to most: more, quite, many, among, commonwealth, inwardly, dung, jotham,
# Nearest to i: ii, you, they, we, he, iii, t, snapper,
# Nearest to american: english, french, british, def, russian, australian, german, delany,
# Average loss at step 42000: 3.437779
# Average loss at step 44000: 3.449353
# Average loss at step 46000: 3.444338
# Average loss at step 48000: 3.353884
# Average loss at step 50000: 3.382835
# Nearest to was: is, became, were, has, be, had, efficiently, nut,
# Nearest to new: second, optimization, vortex, persian, mysia, enlistment, thynne, marrying,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to b: d, c, h, ch, j, f, yards, footballer,
# Nearest to these: some, many, several, both, such, geodesic, they, moseley,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to when: if, while, after, although, before, where, however, but,
# Nearest to zero: five, four, seven, eight, six, nine, two, three,
# Nearest to into: from, through, adair, before, after, repackaged, iridium, catastrophe,
# Nearest to over: through, lep, near, scriptures, into, emmy, onset, euler,
# Nearest to had: has, have, was, were, having, mee, been, won,
# Nearest to one: eight, two, six, seven, four, three, nine, five,
# Nearest to its: their, his, the, convicts, brilliant, her, anhydrous, maintaining,
# Nearest to most: more, many, less, quite, among, gorilla, some, wakes,
# Nearest to i: ii, you, we, t, formosa, n, iii, they,
# Nearest to american: english, french, russian, endian, international, delany, african, australian,
# Average loss at step 52000: 3.435083
# Average loss at step 54000: 3.428763
# Average loss at step 56000: 3.440372
# Average loss at step 58000: 3.395421
# Average loss at step 60000: 3.391566
# Nearest to was: is, became, had, were, has, nut, be, librarian,
# Nearest to new: mysia, distant, enlistment, jahangir, persian, optimization, thynne, second,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to b: d, c, h, r, j, f, z, ch,
# Nearest to these: some, several, many, they, those, all, both, geodesic,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to when: if, after, although, before, while, however, where, until,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to into: from, through, adair, matt, iridium, averse, pocket, over,
# Nearest to over: through, about, between, into, puts, lep, emmy, tolerant,
# Nearest to had: has, have, was, were, having, been, nsw, could,
# Nearest to one: nine, two, seven, eight, six, four, three, five,
# Nearest to its: their, his, the, her, emergency, enhanced, maintaining, une,
# Nearest to most: more, many, some, wakes, all, inwardly, chewed, among,
# Nearest to i: ii, you, we, t, they, he, she, iii,
# Nearest to american: english, british, french, russian, african, australian, endian, international,
# Average loss at step 62000: 3.238354
# Average loss at step 64000: 3.255140
# Average loss at step 66000: 3.405512
# Average loss at step 68000: 3.390721
# Average loss at step 70000: 3.360736
# Nearest to was: is, were, has, became, had, been, sync, be,
# Nearest to new: optimization, jahangir, eichmann, distant, yeo, vortex, thynne, marrying,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to b: d, h, f, r, z, j, p, starling,
# Nearest to these: such, some, many, several, the, are, their, various,
# Nearest to four: five, six, seven, eight, three, nine, zero, two,
# Nearest to when: if, after, while, before, where, although, however, though,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to into: from, through, adair, within, repackaged, averse, matt, alms,
# Nearest to over: through, about, tolerant, euler, goddard, heterosexual, onset, neri,
# Nearest to had: have, has, was, were, having, fijian, never, ausgleich,
# Nearest to one: six, two, seven, eight, four, five, nine, three,
# Nearest to its: their, his, the, her, brilliant, enhanced, disarray, emergency,
# Nearest to most: more, many, less, particularly, quite, all, several, some,
# Nearest to i: ii, we, you, nye, they, p, occupies, he,
# Nearest to american: english, british, australian, international, endian, african, french, designers,
# Average loss at step 72000: 3.372817
# Average loss at step 74000: 3.344802
# Average loss at step 76000: 3.308779
# Average loss at step 78000: 3.349436
# Average loss at step 80000: 3.377266
# Nearest to was: is, became, had, were, has, nut, been, hagia,
# Nearest to new: distant, yeo, zooming, jahangir, old, analytic, persian, henceforth,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to b: d, h, z, r, c, nx, baer, f,
# Nearest to these: several, those, many, some, such, various, both, geodesic,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to when: if, before, after, during, although, though, where, until,
# Nearest to zero: seven, five, six, eight, four, nine, three, two,
# Nearest to into: through, from, adair, within, over, under, down, off,
# Nearest to over: into, about, through, lep, dawn, before, further, trianon,
# Nearest to had: has, have, was, having, were, never, chose, tried,
# Nearest to one: two, seven, six, three, four, five, eight, nine,
# Nearest to its: their, his, her, the, enhanced, our, jermaine, emergency,
# Nearest to most: more, many, particularly, dung, among, some, quite, best,
# Nearest to i: ii, you, we, g, they, n, p, rod,
# Nearest to american: british, international, australian, french, english, designers, russian, mexican,
# Average loss at step 82000: 3.406586
# Average loss at step 84000: 3.411442
# Average loss at step 86000: 3.388926
# Average loss at step 88000: 3.351327
# Average loss at step 90000: 3.360607
# Nearest to was: is, had, became, were, has, nut, been, be,
# Nearest to new: distant, yeo, old, vortex, different, jahangir, janissaries, recent,
# Nearest to can: could, will, may, must, would, should, cannot, might,
# Nearest to b: d, r, z, h, f, starling, ch, j,
# Nearest to these: several, many, some, those, are, various, such, both,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to when: if, after, before, while, where, during, although, until,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to into: through, from, under, repackaged, off, adair, down, matt,
# Nearest to over: lep, about, sowing, between, through, lac, gurps, off,
# Nearest to had: has, have, was, were, having, chose, since, never,
# Nearest to one: seven, four, five, eight, six, three, two, nine,
# Nearest to its: their, his, her, the, relinquishing, enhanced, whose, your,
# Nearest to most: more, many, less, particularly, some, chihuahua, all, several,
# Nearest to i: ii, we, you, t, n, g, mathrm, starling,
# Nearest to american: british, australian, french, russian, english, mexican, international, designers,
# Average loss at step 92000: 3.401245
# Average loss at step 94000: 3.252300
# Average loss at step 96000: 3.357634
# Average loss at step 98000: 3.235324
# Average loss at step 100000: 3.357605
# Nearest to was: is, became, had, has, were, been, nut, after,
# Nearest to new: distant, different, jahangir, vortex, abaci, mysia, janissaries, rewards,
# Nearest to can: could, may, would, will, must, should, cannot, might,
# Nearest to b: d, galahad, hx, sailboat, kenyon, z, manz, menzies,
# Nearest to these: several, many, some, those, various, different, their, certain,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to when: if, before, although, while, after, where, though, during,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to into: through, from, off, in, within, repackaged, adair, under,
# Nearest to over: between, lep, about, within, through, off, gurps, oktoberfest,
# Nearest to had: has, have, was, having, were, chose, is, mee,
# Nearest to one: seven, two, four, eight, six, three, five, nine,
# Nearest to its: their, his, the, her, whose, our, fret, relinquishing,
# Nearest to most: more, less, dung, many, especially, soloist, particularly, wakes,
# Nearest to i: we, you, ii, they, mathrm, t, he, n,
# Nearest to american: british, australian, hh, french, international, canadian, solidifying, delany,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  session.run(tf.initialize_all_variables())
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
